# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\xray.jpg",0)
result=cv2.equalizeHist(image)
plt.figure(figsize=[12,7])
plt.subplot(221);plt.imshow(image,cmap="gray");plt.title("X_ray image")
plt.subplot(222);plt.hist(image.ravel(),256);plt.title("X_ray hist")
plt.subplot(223);plt.imshow(result,cmap="gray");plt.title("result equalize")
plt.subplot(224);plt.hist(result.ravel(),256);plt.title("result hist")
plt.show()

# %%
image=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\0033.jpeg",0)
clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
result=clahe.apply(image)
plt.figure(figsize=[12,7])
plt.subplot(221);plt.imshow(image,cmap="gray");plt.title(" image");
plt.subplot(222);plt.imshow(result,cmap="gray");plt.title("adptive");

# %%
image=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\002.jpg",0)
clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
result=clahe.apply(image)
plt.figure(figsize=[12,7])
plt.subplot(221);plt.imshow(image,cmap="gray");plt.title(" image");
plt.subplot(222);plt.imshow(result,cmap="gray");plt.title("adptive");

# %%
image=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\0033.jpeg")
channels=cv2.split(image)
eq_channels=[]
for ch in channels:
    eq_channels.append(clahe.apply(ch))
eq_clahe_image=cv2.merge(eq_channels)
eq_channels=[]
for ch in channels:
    eq_channels.append(cv2.equalizeHist(ch))
eq_image=cv2.merge(eq_channels)
plt.figure(figsize=[15,15])
plt.subplot(321);plt.imshow(image,cmap="gray");plt.title(" orginal");
plt.subplot(323);plt.imshow(eq_clahe_image[...,::-1]);plt.title("adaptive equalize");
plt.subplot(325);plt.imshow(eq_image[...,::-1]);plt.title("global clahe");
color=("b","g","r")

plt.subplot(322);
for i, col in enumerate(color):
    histogram=cv2.calcHist([image],[i],None,[256],[0,256])
    plt.plot(histogram,color=col)
    
plt.subplot(324);
for i, col in enumerate(color):
    histogram=cv2.calcHist([eq_clahe_image],[i],None,[256],[0,256])
    plt.plot(histogram,color=col)
    
plt.subplot(326); 
for i, col in enumerate(color):
    histogram=cv2.calcHist([eq_image],[i],None,[256],[0,256])
    plt.plot(histogram,color=col)

# %%
image1=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\001.jpg",0)
image2=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\02.jpg",0)

histogram1=cv2.calcHist([image1],[0],None,[256],[0,256])
histogram2=cv2.calcHist([image2],[0],None,[256],[0,256])

histogram1_normalized=histogram1.copy()
histogram2_normalized=histogram2.copy()

cv2.normalize(histogram1,histogram1_normalized,alpha=0,beta=1,norm_type=cv2.NORM_MINMAX)
cv2.normalize(histogram2,histogram2_normalized,alpha=0,beta=1,norm_type=cv2.NORM_MINMAX)
plt.figure(figsize=[10,7])
plt.subplot(221);plt.plot(histogram1);plt.title("Bigger before normalize");
plt.subplot(222);plt.plot(histogram2);plt.title("Smaller before normalize");
plt.subplot(223);plt.plot(histogram1_normalized);plt.title("Bigger after normalize");
plt.subplot(224);plt.plot(histogram2_normalized);plt.title("Smaller after normalize");
