# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
dark=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\cube-dark.png")
bright=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\cube-bright.png")
plt.figure(figsize=[11,11])
plt.subplot(331);plt.imshow(bright[...,::-1]);plt.title("bright");
plt.subplot(332);plt.imshow(dark[...,::-1]);plt.title("dark");
plt.subplot(334);plt.imshow(bright[...,0],cmap="gray");plt.title("bright-blue");
plt.subplot(335);plt.imshow(bright[...,1],cmap="gray");plt.title("bright-green");
plt.subplot(336);plt.imshow(bright[...,2],cmap="gray");plt.title("bright-red");
plt.subplot(337);plt.imshow(dark[...,0],cmap="gray");plt.title("dark-blue");
plt.subplot(338);plt.imshow(dark[...,1],cmap="gray");plt.title("dark-green");
plt.subplot(339);plt.imshow(dark[...,2],cmap="gray");plt.title("dark-red");
plt.show()

# BGR

# %%
dark=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\cube-dark.png")
bright=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\cube-bright.png")
plt.figure(figsize=[11,11])
dark1=cv2.cvtColor(dark,cv2.COLOR_BGR2HSV)
bright1=cv2.cvtColor(bright,cv2.COLOR_BGR2HSV)

plt.subplot(331);plt.imshow(bright[...,::-1]);plt.title("bright");
plt.subplot(332);plt.imshow(dark[...,::-1]);plt.title("dark");
plt.subplot(334);plt.imshow(bright1[...,0],cmap="gray");plt.title("bright-blue");
plt.subplot(335);plt.imshow(bright1[...,1],cmap="gray");plt.title("bright-green");
plt.subplot(336);plt.imshow(bright1[...,2],cmap="gray");plt.title("bright-red");
plt.subplot(337);plt.imshow(dark1[...,0],cmap="gray");plt.title("dark-blue");
plt.subplot(338);plt.imshow(dark1[...,1],cmap="gray");plt.title("dark-green");
plt.subplot(339);plt.imshow(dark1[...,2],cmap="gray");plt.title("dark-red");
plt.show()

# HSV

# %%
dark=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\cube-dark.png")
bright=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\cube-bright.png")
plt.figure(figsize=[11,11])
dark1=cv2.cvtColor(dark,cv2.COLOR_BGR2LAB)
bright1=cv2.cvtColor(bright,cv2.COLOR_BGR2LAB)

plt.subplot(331);plt.imshow(bright[...,::-1]);plt.title("bright");
plt.subplot(332);plt.imshow(dark[...,::-1]);plt.title("dark");
plt.subplot(334);plt.imshow(bright1[...,0],cmap="gray");plt.title("bright-blue");
plt.subplot(335);plt.imshow(bright1[...,1],cmap="gray");plt.title("bright-green");
plt.subplot(336);plt.imshow(bright1[...,2],cmap="gray");plt.title("bright-red");
plt.subplot(337);plt.imshow(dark1[...,0],cmap="gray");plt.title("dark-blue");
plt.subplot(338);plt.imshow(dark1[...,1],cmap="gray");plt.title("dark-green");
plt.subplot(339);plt.imshow(dark1[...,2],cmap="gray");plt.title("dark-red");
plt.show()

# LAB

# %%
dark=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\cube-dark.png")
bright=cv2.imread(r"C:\\Users\\Student\\Desktop\\pic\\cube-bright.png")
plt.figure(figsize=[11,11])
dark1=cv2.cvtColor(dark,cv2.COLOR_BGR2YCrCb)
bright1=cv2.cvtColor(bright,cv2.COLOR_BGR2YCrCb)

plt.subplot(331);plt.imshow(bright[...,::-1]);plt.title("bright");
plt.subplot(332);plt.imshow(dark[...,::-1]);plt.title("dark");
plt.subplot(334);plt.imshow(bright1[...,0],cmap="gray");plt.title("bright-blue");
plt.subplot(335);plt.imshow(bright1[...,1],cmap="gray");plt.title("bright-green");
plt.subplot(336);plt.imshow(bright1[...,2],cmap="gray");plt.title("bright-red");
plt.subplot(337);plt.imshow(dark1[...,0],cmap="gray");plt.title("dark-blue");
plt.subplot(338);plt.imshow(dark1[...,1],cmap="gray");plt.title("dark-green");
plt.subplot(339);plt.imshow(dark1[...,2],cmap="gray");plt.title("dark-red");
plt.show()

# YCrCB
